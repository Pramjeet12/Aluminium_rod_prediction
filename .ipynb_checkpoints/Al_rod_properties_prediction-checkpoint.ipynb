# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\ASUS\Downloads\aluminum_wire_rod_synthetic.csv")

# %%
data.head()
# Out:
#    CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 0             517.738762             2.670609          2.124924
# 1             516.073516             4.669137          1.951931
# 2             514.097405             4.114840          2.440798
# 3             458.507464             4.946501          1.770175
# 4             502.823147             3.941969          0.611059
#
#    ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 0                 97.462870                  1.343437
# 1                 96.631344                  0.341770
# 2                 97.577301                  0.732053
# 3                 98.004922                  1.253575
# 4                 99.038671                  0.430471
#
#    ChemicalComposition(Mg%)  ChemicalComposition(Si%)  \
# 0                  0.525344                  0.444815
# 1                  0.441299                  0.348098
# 2                  0.685939                  0.514107
# 3                  0.538860                  0.654862
# 4                  0.382711                  0.258164
#
#    ChemicalComposition(Fe%)  CastBarEntryTemperature(C)  \
# 0                  0.490581                  491.115463
# 1                  0.057907                  487.230742
# 2                  0.114230                  499.414772
# 3                  0.022023                  482.274552
# 4                  0.112907                  482.832877
#
#    EmulsionTemperature(C)  AgingTemperature(C)  EmulsionPressure(Bar)  \
# 0               57.784047           131.553475               2.021540
# 1               47.210994           188.833423               1.241971
# 2               35.371321           160.081995               1.189000
# 3               37.323106           195.955782               1.196973
# 4               49.291255           164.550011               2.635293
#
#    EmulsionConcentration(%)  RodQuenchWaterPressure(Bar)  \
# 0                 10.924512                     1.911485
# 1                  5.930472                     1.490504
# 2                 15.647929                     1.016605
# 3                 16.240096                     1.200268
# 4                 12.134603                     1.147047
#
#    FirstRollingTemperature(C)  QuenchingTemperature(C)  Elongation(%)  \
# 0                  379.700915               101.000534      79.004379
# 1                  378.013517                84.488970      78.148739
# 2                  357.882869               170.277026      76.589026
# 3                  398.440959               246.248071      66.702291
# 4                  386.619820               209.584435      73.947378
#
#    Conductivity(%IACS)    UTS(Mpa)
# 0            46.183274  151.816979
# 1            45.231306  149.161207
# 2            43.895326  141.849935
# 3            43.427165  157.580112
# 4            44.451037  163.040135

# %%
data.tail()
# Out:
#       CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 9995             450.896112             1.591570          2.469588
# 9996             454.236645             2.620234          2.536631
# 9997             496.007223             2.725959          2.837583
# 9998             503.590094             1.449964          1.766031
# 9999             472.481583             4.524516          2.319007
#
#       ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 9995                 95.141012                  1.371089
# 9996                 99.230694                  0.268305
# 9997                 97.023051                  1.240611
# 9998                 96.396007                  1.087624
# 9999                 99.419067                  1.365180
#
#       ChemicalComposition(Mg%)  ChemicalComposition(Si%)  \
# 9995                  0.408244                  0.498955
# 9996                  0.739965                  0.629989
# 9997                  0.860949                  0.479421
# 9998                  0.546962                  0.433402
# 9999                  0.441399                  0.624778
#
#       ChemicalComposition(Fe%)  CastBarEntryTemperature(C)  \
# 9995                  0.331345                  475.927353
# 9996                  0.368739                  489.996267
# 9997                  0.480947                  479.229347
# 9998                  0.551632                  481.911435
# 9999                  0.295950                  498.701535
#
#       EmulsionTemperature(C)  AgingTemperature(C)  EmulsionPressure(Bar)  \
# 9995               37.330197           168.137417               1.218003
# 9996               34.205107           182.084438               2.778060
# 9997               47.300477           163.777674               2.766738
# 9998               43.616076           148.665971               1.056156
# 9999               42.255541           161.702058               2.871769
#
#       EmulsionConcentration(%)  RodQuenchWaterPressure(Bar)  \
# 9995                  9.607747                     1.787915
# 9996                 15.673892                     1.509274
# 9997                  7.641202                     1.379547
# 9998                 19.184621                     1.159013
# 9999                 16.365792                     1.555163
#
#       FirstRollingTemperature(C)  QuenchingTemperature(C)  Elongation(%)  \
# 9995                  392.042724                36.043359      70.246691
# 9996                  373.993115               227.599118      70.575571
# 9997                  370.938045                11.783743      75.721106
# 9998                  351.720736               203.929566      77.175560
# 9999                  382.485063               229.990558      70.947047
#
#       Conductivity(%IACS)    UTS(Mpa)
# 9995            42.916029  162.476887
# 9996            44.014963  151.391820
# 9997            45.213703  144.549297
# 9998            43.742988  154.972563
# 9999            44.780476  155.620165

# %%
data.sample(15)
# Out:
#       CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 8037             517.920005             3.280149          1.821916
# 7861             514.579737             3.032714          0.788460
# 8886             510.780125             3.989576          2.456717
# 922              514.936032             2.834234          0.957876
# 3273             501.616053             1.590271          1.565883
# 9724             484.352095             1.010581          0.719883
# 3085             468.645254             2.218474          2.121610
# 2882             489.539359             2.131989          1.326833
# 5531             480.142943             3.504636          0.779221
# 8302             494.142108             4.753582          2.417318
# 5731             466.124682             2.326465          1.186723
# 2253             501.632395             1.683443          2.172336
# 8881             485.144121             4.271593          2.603102
# 1483             486.078155             1.465562          2.399372
# 1987             485.576334             4.141639          2.805205
#
#       ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 8037                 98.700120                  0.348810
# 7861                 95.716454                  0.696204
# 8886                 97.810669                  0.531648
# 922                  96.918848                  0.338144
# 3273                 98.225198                  1.222651
# 9724                 96.045009                  1.221341
# 3085                 97.226357                  0.506376
# 2882                 98.737385                  0.805712
# 5531                 99.261509                  1.404801
# 8302                 97.554057                  0.448481
# 5731                 96.066290                  1.199724
# 2253                 98.380392                  0.521238
# 8881                 96.818379                  1.284283
# 1483                 96.979185                  1.227539
# 1987                 96.858726                  1.222797
#
#       ChemicalComposition(Mg%)  ChemicalComposition(Si%)  \
# 8037                  0.706698                  0.544541
# 7861                  0.329860                  0.470638
# 8886                  0.373549                  0.441137
# 922                   0.686578                  0.324222
# 3273                  0.611699                  0.544515
# 9724                  0.615164                  0.632968
# 3085                  0.601673                  0.394732
# 2882                  0.875985                  0.713705
# 5531                  0.620917                  0.297660
# 8302                  0.505414                  0.383828
# 5731                  0.856879                  0.359342
# 2253                  0.441039                  0.449886
# 8881                  0.739115                  0.630882
# 1483                  0.565192                  0.336196
# 1987                  0.719075                  0.452663
#
#       ChemicalComposition(Fe%)  CastBarEntryTemperature(C)  \
# 8037                  0.236248                  488.631333
# 7861                  0.276769                  487.751750
# 8886                  0.193053                  471.095342
# 922                   0.189451                  476.569144
# 3273                  0.123082                  472.840641
# 9724                  0.100996                  475.671969
# 3085                  0.541700                  473.766241
# 2882                  0.016516                  483.598342
# 5531                  0.319218                  492.621771
# 8302                  0.431923                  499.829748
# 5731                  0.395053                  490.115353
# 2253                  0.146195                  471.697384
# 8881                  0.220206                  473.992124
# 1483                  0.494636                  470.525824
# 1987                  0.190827                  492.120919
#
#       EmulsionTemperature(C)  AgingTemperature(C)  EmulsionPressure(Bar)  \
# 8037               34.499139           146.258310               2.345435
# 7861               47.279328           147.484478               1.246359
# 8886               64.216646           168.672784               1.026869
# 922                32.310460           136.545709               1.438509
# 3273               67.852258           158.159346               1.160857
# 9724               40.106051           177.040204               1.611798
# 3085               47.538999           181.035882               2.817008
# 2882               30.908375           187.128526               1.064276
# 5531               59.104077           170.248361               1.364092
# 8302               60.609095           156.472632               1.320634
# 5731               35.524135           189.368167               2.911419
# 2253               36.071564           139.293449               1.071469
# 8881               44.185879           190.007257               2.855842
# 1483               48.870031           141.321869               2.721811
# 1987               66.298362           133.163913               2.138101
#
#       EmulsionConcentration(%)  RodQuenchWaterPressure(Bar)  \
# 8037                 16.756281                     1.050782
# 7861                 12.191876                     1.504608
# 8886                 13.139546                     1.097746
# 922                  11.224188                     1.531453
# 3273                 13.736735                     1.721443
# 9724                  6.918473                     1.881345
# 3085                  5.471737                     1.105790
# 2882                  5.868356                     1.838788
# 5531                 14.168740                     1.255637
# 8302                  5.216668                     1.274912
# 5731                 15.812594                     1.066819
# 2253                 13.996974                     1.752340
# 8881                  9.822741                     1.805165
# 1483                 10.875298                     1.773563
# 1987                 13.623459                     1.835209
#
#       FirstRollingTemperature(C)  QuenchingTemperature(C)  Elongation(%)  \
# 8037                  364.452641               106.972761      76.419445
# 7861                  396.258821               155.177514      80.211369
# 8886                  379.896001                 1.322587      77.438320
# 922                   366.930217                 6.242459      80.708359
# 3273                  397.339300                32.561950      77.675275
# 9724                  398.560593                68.632058      74.089281
# 3085                  388.555502               218.503391      68.982412
# 2882                  360.018924                78.856305      74.437962
# 5531                  389.367146               158.451582      72.559632
# 8302                  352.544680                98.917064      76.173249
# 5731                  359.107467               191.649533      69.364413
# 2253                  387.522627               135.858389      76.614542
# 8881                  388.143841                87.492972      74.805082
# 1483                  357.180575               253.235934      73.266640
# 1987                  364.579178                40.621032      73.262591
#
#       Conductivity(%IACS)    UTS(Mpa)
# 8037            43.111527  145.645314
# 7861            43.297681  153.854995
# 8886            47.312959  159.578339
# 922             42.216595  141.293270
# 3273            45.872945  157.608848
# 9724            41.404248  168.764214
# 3085            44.500144  154.177389
# 2882            42.936054  150.940687
# 5531            45.137743  155.543089
# 8302            46.179470  138.986421
# 5731            42.876630  139.037165
# 2253            44.692159  162.282072
# 8881            44.822583  155.233253
# 1483            44.648354  141.086834
# 1987            47.018528  144.372802

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CastingTemperature(C)        10000 non-null  float64
#  1   RollingSpeed(m/min)          10000 non-null  float64
#  2   CoolingRate(C/s)             10000 non-null  float64
#  3   ChemicalComposition(Al%)     10000 non-null  float64
#  4   ChemicalComposition(Cu%)     10000 non-null  float64
#  5   ChemicalComposition(Mg%)     10000 non-null  float64
#  6   ChemicalComposition(Si%)     10000 non-null  float64
#  7   ChemicalComposition(Fe%)     10000 non-null  float64
#  8   CastBarEntryTemperature(C)   10000 non-null  float64
#  9   EmulsionTemperature(C)       10000 non-null  float64
#  10  AgingTemperature(C)          10000 non-null  float64
#  11  EmulsionPressure(Bar)        10000 non-null  float64
#  12  EmulsionConcentration(%)     10000 non-null  float64
#  13  RodQuenchWaterPressure(Bar)  10000 non-null  float64
#  14  FirstRollingTemperature(C)   10000 non-null  float64
#  15  QuenchingTemperature(C)      10000 non-null  float64
#  16  Elongation(%)                10000 non-null  float64
#  17  Conductivity(%IACS)          10000 non-null  float64
#  18  UTS(Mpa)                     10000 non-null  float64
# dtypes: float64(19)
# memory usage: 1.4 MB

# %%
data.describe()
# Out:
#        CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# count           10000.000000         10000.000000      10000.000000
# mean              485.100301             2.999822          1.741335
# std                20.200657             1.160946          0.724717
# min               450.005874             1.000230          0.500046
# 25%               467.728565             1.989422          1.111139
# 50%               484.980155             3.009923          1.731530
# 75%               502.420843             3.993998          2.370437
# max               519.994796             4.999955          2.999944
#
#        ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# count              10000.000000              10000.000000
# mean                  97.236129                  0.797193
# std                    1.302841                  0.403958
# min                   95.000018                  0.100020
# 25%                   96.099753                  0.442297
# 50%                   97.220408                  0.803133
# 75%                   98.379422                  1.145900
# max                   99.499657                  1.499440
#
#        ChemicalComposition(Mg%)  ChemicalComposition(Si%)  \
# count              10000.000000              10000.000000
# mean                   0.600565                  0.499178
# std                    0.172866                  0.144221
# min                    0.300124                  0.250125
# 25%                    0.452345                  0.372909
# 50%                    0.598263                  0.498167
# 75%                    0.751706                  0.624405
# max                    0.899723                  0.749982
#
#        ChemicalComposition(Fe%)  CastBarEntryTemperature(C)  \
# count              10000.000000                10000.000000
# mean                   0.301675                  485.210153
# std                    0.172355                    8.697949
# min                    0.000013                  470.003508
# 25%                    0.154923                  477.669714
# 50%                    0.303286                  485.331185
# 75%                    0.450319                  492.758656
# max                    0.599987                  499.995696
#
#        EmulsionTemperature(C)  AgingTemperature(C)  EmulsionPressure(Bar)  \
# count            10000.000000         10000.000000           10000.000000
# mean                50.092215           165.081655               2.005011
# std                 11.608543            20.284804               0.580532
# min                 30.006344           130.002259               1.000325
# 25%                 39.932094           147.517198               1.499516
# 50%                 50.262753           165.224613               2.009016
# 75%                 60.070574           182.752426               2.508564
# max                 69.996184           199.996430               2.999962
#
#        EmulsionConcentration(%)  RodQuenchWaterPressure(Bar)  \
# count              10000.000000                 10000.000000
# mean                  12.554012                     1.501083
# std                    4.341256                     0.289346
# min                    5.000904                     1.000036
# 25%                    8.761917                     1.251006
# 50%                   12.540099                     1.502383
# 75%                   16.351312                     1.752044
# max                   19.998153                     1.999784
#
#        FirstRollingTemperature(C)  QuenchingTemperature(C)  Elongation(%)  \
# count                10000.000000             10000.000000   10000.000000
# mean                   374.862245               130.417016      73.500681
# std                     14.297815                75.020612       3.398692
# min                    350.001639                 0.008459      63.102913
# 25%                    362.752774                65.827898      70.859433
# 50%                    374.782696               129.436530      73.534830
# 75%                    386.846383               195.843804      76.123614
# max                    399.991062               259.995252      83.811338
#
#        Conductivity(%IACS)      UTS(Mpa)
# count         10000.000000  10000.000000
# mean             44.788483    150.637652
# std               1.416928      7.567277
# min              40.586724    126.093015
# 25%              43.742930    145.127997
# 50%              44.791165    150.696303
# 75%              45.830007    156.034357
# max              48.914756    175.927498

# %%
data.shape
# Out:
# (10000, 19)

# %%
data.size
# Out:
# 190000

# %%
data.isnull().sum()
# Out:
# CastingTemperature(C)          0
# RollingSpeed(m/min)            0
# CoolingRate(C/s)               0
# ChemicalComposition(Al%)       0
# ChemicalComposition(Cu%)       0
# ChemicalComposition(Mg%)       0
# ChemicalComposition(Si%)       0
# ChemicalComposition(Fe%)       0
# CastBarEntryTemperature(C)     0
# EmulsionTemperature(C)         0
# AgingTemperature(C)            0
# EmulsionPressure(Bar)          0
# EmulsionConcentration(%)       0
# RodQuenchWaterPressure(Bar)    0
# FirstRollingTemperature(C)     0
# QuenchingTemperature(C)        0
# Elongation(%)                  0
# Conductivity(%IACS)            0
# UTS(Mpa)                       0
# dtype: int64

# %%
newdata = data.drop(["ChemicalComposition(Mg%)", "ChemicalComposition(Si%)", "CastBarEntryTemperature(C)", "AgingTemperature(C)", "RodQuenchWaterPressure(Bar)", "FirstRollingTemperature(C)", "QuenchingTemperature(C)"], axis="columns")
newdata.head()
# Out:
#    CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 0             517.738762             2.670609          2.124924
# 1             516.073516             4.669137          1.951931
# 2             514.097405             4.114840          2.440798
# 3             458.507464             4.946501          1.770175
# 4             502.823147             3.941969          0.611059
#
#    ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 0                 97.462870                  1.343437
# 1                 96.631344                  0.341770
# 2                 97.577301                  0.732053
# 3                 98.004922                  1.253575
# 4                 99.038671                  0.430471
#
#    ChemicalComposition(Fe%)  EmulsionTemperature(C)  EmulsionPressure(Bar)  \
# 0                  0.490581               57.784047               2.021540
# 1                  0.057907               47.210994               1.241971
# 2                  0.114230               35.371321               1.189000
# 3                  0.022023               37.323106               1.196973
# 4                  0.112907               49.291255               2.635293
#
#    EmulsionConcentration(%)  Elongation(%)  Conductivity(%IACS)    UTS(Mpa)
# 0                 10.924512      79.004379            46.183274  151.816979
# 1                  5.930472      78.148739            45.231306  149.161207
# 2                 15.647929      76.589026            43.895326  141.849935
# 3                 16.240096      66.702291            43.427165  157.580112
# 4                 12.134603      73.947378            44.451037  163.040135

# %%
newdata.tail()
# Out:
#       CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 9995             450.896112             1.591570          2.469588
# 9996             454.236645             2.620234          2.536631
# 9997             496.007223             2.725959          2.837583
# 9998             503.590094             1.449964          1.766031
# 9999             472.481583             4.524516          2.319007
#
#       ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 9995                 95.141012                  1.371089
# 9996                 99.230694                  0.268305
# 9997                 97.023051                  1.240611
# 9998                 96.396007                  1.087624
# 9999                 99.419067                  1.365180
#
#       ChemicalComposition(Fe%)  EmulsionTemperature(C)  EmulsionPressure(Bar)  \
# 9995                  0.331345               37.330197               1.218003
# 9996                  0.368739               34.205107               2.778060
# 9997                  0.480947               47.300477               2.766738
# 9998                  0.551632               43.616076               1.056156
# 9999                  0.295950               42.255541               2.871769
#
#       EmulsionConcentration(%)  Elongation(%)  Conductivity(%IACS)    UTS(Mpa)
# 9995                  9.607747      70.246691            42.916029  162.476887
# 9996                 15.673892      70.575571            44.014963  151.391820
# 9997                  7.641202      75.721106            45.213703  144.549297
# 9998                 19.184621      77.175560            43.742988  154.972563
# 9999                 16.365792      70.947047            44.780476  155.620165

# %%
newdata.sample(15)
# Out:
#       CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 7412             498.193682             2.680574          0.654158
# 2022             473.556770             2.275129          0.629895
# 7242             476.806900             1.544727          1.242547
# 7649             502.031387             3.024806          2.172294
# 3775             467.525299             3.627351          1.860726
# 2788             463.783116             3.638881          0.526853
# 3682             453.297201             4.423984          2.985406
# 5532             507.461171             1.551542          0.838893
# 65               513.963435             1.620497          2.982469
# 2739             511.179993             2.586878          2.944115
# 3544             509.738383             3.792837          2.140897
# 9609             503.003212             2.232755          1.739349
# 1406             496.686742             1.317943          1.495557
# 3793             484.483321             3.115345          1.246754
# 5154             500.815736             1.560836          1.976137
#
#       ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 7412                 97.959845                  1.111553
# 2022                 98.737382                  0.968975
# 7242                 97.946052                  1.484830
# 7649                 98.201327                  0.417981
# 3775                 98.277456                  0.479656
# 2788                 96.525821                  0.647228
# 3682                 96.387265                  1.101747
# 5532                 95.471783                  1.383262
# 65                   95.493918                  0.166080
# 2739                 98.418977                  1.324801
# 3544                 95.118957                  0.703943
# 9609                 96.898266                  0.295017
# 1406                 98.502986                  1.416908
# 3793                 95.965321                  0.181714
# 5154                 98.733744                  0.408704
#
#       ChemicalComposition(Fe%)  EmulsionTemperature(C)  EmulsionPressure(Bar)  \
# 7412                  0.287975               42.718931               1.380950
# 2022                  0.020565               56.315422               1.228589
# 7242                  0.091587               50.089190               2.101993
# 7649                  0.118911               64.078575               2.636283
# 3775                  0.343930               47.044149               1.771062
# 2788                  0.436108               62.636603               1.015686
# 3682                  0.456492               45.831042               1.825834
# 5532                  0.549187               58.622608               1.852212
# 65                    0.305068               31.922767               2.144053
# 2739                  0.016992               55.000663               2.494673
# 3544                  0.038476               39.228577               2.829727
# 9609                  0.178826               62.255137               1.952627
# 1406                  0.303146               39.919034               1.428945
# 3793                  0.567369               36.698305               2.449603
# 5154                  0.143603               32.080831               2.258305
#
#       EmulsionConcentration(%)  Elongation(%)  Conductivity(%IACS)    UTS(Mpa)
# 7412                 15.311581      72.047938            43.743414  141.423439
# 2022                 18.161463      72.646243            45.584781  141.191144
# 7242                  5.822418      72.836335            45.610790  156.797339
# 7649                 10.448310      74.927204            46.478673  158.917895
# 3775                 12.885036      72.878109            45.673443  146.320616
# 2788                 14.182235      69.520155            45.619734  153.873747
# 3682                 14.360295      69.269235            45.014085  157.838775
# 5532                 10.975071      76.846276            44.376320  149.106035
# 65                   10.951501      78.057363            43.843166  144.217813
# 2739                  7.427595      78.183454            46.008446  161.994349
# 3544                  8.015647      77.453606            43.806982  148.015830
# 9609                 15.242371      78.292445            47.143513  141.194932
# 1406                 18.071837      72.987549            44.263138  153.509582
# 3793                  6.674105      73.990799            43.595176  149.026180
# 5154                 12.034900      76.963392            43.948404  150.081540

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CastingTemperature(C)     10000 non-null  float64
#  1   RollingSpeed(m/min)       10000 non-null  float64
#  2   CoolingRate(C/s)          10000 non-null  float64
#  3   ChemicalComposition(Al%)  10000 non-null  float64
#  4   ChemicalComposition(Cu%)  10000 non-null  float64
#  5   ChemicalComposition(Fe%)  10000 non-null  float64
#  6   EmulsionTemperature(C)    10000 non-null  float64
#  7   EmulsionPressure(Bar)     10000 non-null  float64
#  8   EmulsionConcentration(%)  10000 non-null  float64
#  9   Elongation(%)             10000 non-null  float64
#  10  Conductivity(%IACS)       10000 non-null  float64
#  11  UTS(Mpa)                  10000 non-null  float64
# dtypes: float64(12)
# memory usage: 937.6 KB

# %%
newdata.describe()
# Out:
#        CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# count           10000.000000         10000.000000      10000.000000
# mean              485.100301             2.999822          1.741335
# std                20.200657             1.160946          0.724717
# min               450.005874             1.000230          0.500046
# 25%               467.728565             1.989422          1.111139
# 50%               484.980155             3.009923          1.731530
# 75%               502.420843             3.993998          2.370437
# max               519.994796             4.999955          2.999944
#
#        ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# count              10000.000000              10000.000000
# mean                  97.236129                  0.797193
# std                    1.302841                  0.403958
# min                   95.000018                  0.100020
# 25%                   96.099753                  0.442297
# 50%                   97.220408                  0.803133
# 75%                   98.379422                  1.145900
# max                   99.499657                  1.499440
#
#        ChemicalComposition(Fe%)  EmulsionTemperature(C)  \
# count              10000.000000            10000.000000
# mean                   0.301675               50.092215
# std                    0.172355               11.608543
# min                    0.000013               30.006344
# 25%                    0.154923               39.932094
# 50%                    0.303286               50.262753
# 75%                    0.450319               60.070574
# max                    0.599987               69.996184
#
#        EmulsionPressure(Bar)  EmulsionConcentration(%)  Elongation(%)  \
# count           10000.000000              10000.000000   10000.000000
# mean                2.005011                 12.554012      73.500681
# std                 0.580532                  4.341256       3.398692
# min                 1.000325                  5.000904      63.102913
# 25%                 1.499516                  8.761917      70.859433
# 50%                 2.009016                 12.540099      73.534830
# 75%                 2.508564                 16.351312      76.123614
# max                 2.999962                 19.998153      83.811338
#
#        Conductivity(%IACS)      UTS(Mpa)
# count         10000.000000  10000.000000
# mean             44.788483    150.637652
# std               1.416928      7.567277
# min              40.586724    126.093015
# 25%              43.742930    145.127997
# 50%              44.791165    150.696303
# 75%              45.830007    156.034357
# max              48.914756    175.927498

# %%
newdata.shape
# Out:
# (10000, 12)

# %%
newdata.size
# Out:
# 120000

# %%
newdata.isnull().sum()
# Out:
# CastingTemperature(C)       0
# RollingSpeed(m/min)         0
# CoolingRate(C/s)            0
# ChemicalComposition(Al%)    0
# ChemicalComposition(Cu%)    0
# ChemicalComposition(Fe%)    0
# EmulsionTemperature(C)      0
# EmulsionPressure(Bar)       0
# EmulsionConcentration(%)    0
# Elongation(%)               0
# Conductivity(%IACS)         0
# UTS(Mpa)                    0
# dtype: int64

# %%
X = newdata.drop(["Elongation(%)", "Conductivity(%IACS)", "UTS(Mpa)"], axis="columns")
X.head()
# Out:
#    CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 0             517.738762             2.670609          2.124924
# 1             516.073516             4.669137          1.951931
# 2             514.097405             4.114840          2.440798
# 3             458.507464             4.946501          1.770175
# 4             502.823147             3.941969          0.611059
#
#    ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 0                 97.462870                  1.343437
# 1                 96.631344                  0.341770
# 2                 97.577301                  0.732053
# 3                 98.004922                  1.253575
# 4                 99.038671                  0.430471
#
#    ChemicalComposition(Fe%)  EmulsionTemperature(C)  EmulsionPressure(Bar)  \
# 0                  0.490581               57.784047               2.021540
# 1                  0.057907               47.210994               1.241971
# 2                  0.114230               35.371321               1.189000
# 3                  0.022023               37.323106               1.196973
# 4                  0.112907               49.291255               2.635293
#
#    EmulsionConcentration(%)
# 0                 10.924512
# 1                  5.930472
# 2                 15.647929
# 3                 16.240096
# 4                 12.134603

# %%
Y=newdata.drop(["CastingTemperature(C)", "RollingSpeed(m/min)", "CoolingRate(C/s)", "ChemicalComposition(Al%)", "ChemicalComposition(Cu%)", "ChemicalComposition(Fe%)", "EmulsionTemperature(C)", "EmulsionPressure(Bar)", "EmulsionConcentration(%)"], axis="columns")
Y.head()
# Out:
#    Elongation(%)  Conductivity(%IACS)    UTS(Mpa)
# 0      79.004379            46.183274  151.816979
# 1      78.148739            45.231306  149.161207
# 2      76.589026            43.895326  141.849935
# 3      66.702291            43.427165  157.580112
# 4      73.947378            44.451037  163.040135

# %%
X
# Out:
#       CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 0                517.738762             2.670609          2.124924
# 1                516.073516             4.669137          1.951931
# 2                514.097405             4.114840          2.440798
# 3                458.507464             4.946501          1.770175
# 4                502.823147             3.941969          0.611059
# ...                     ...                  ...               ...
# 9995             450.896112             1.591570          2.469588
# 9996             454.236645             2.620234          2.536631
# 9997             496.007223             2.725959          2.837583
# 9998             503.590094             1.449964          1.766031
# 9999             472.481583             4.524516          2.319007
#
#       ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 0                    97.462870                  1.343437
# 1                    96.631344                  0.341770
# 2                    97.577301                  0.732053
# 3                    98.004922                  1.253575
# 4                    99.038671                  0.430471
# ...                        ...                       ...
# 9995                 95.141012                  1.371089
# 9996                 99.230694                  0.268305
# 9997                 97.023051                  1.240611
# 9998                 96.396007                  1.087624
# 9999                 99.419067                  1.365180
#
#       ChemicalComposition(Fe%)  EmulsionTemperature(C)  EmulsionPressure(Bar)  \
# 0                     0.490581               57.784047               2.021540
# 1                     0.057907               47.210994               1.241971
# 2                     0.114230               35.371321               1.189000
# 3                     0.022023               37.323106               1.196973
# 4                     0.112907               49.291255               2.635293
# ...                        ...                     ...                    ...
# 9995                  0.331345               37.330197               1.218003
# 9996                  0.368739               34.205107               2.778060
# 9997                  0.480947               47.300477               2.766738
# 9998                  0.551632               43.616076               1.056156
# 9999                  0.295950               42.255541               2.871769
#
#       EmulsionConcentration(%)
# 0                    10.924512
# 1                     5.930472
# 2                    15.647929
# 3                    16.240096
# 4                    12.134603
# ...                        ...
# 9995                  9.607747
# 9996                 15.673892
# 9997                  7.641202
# 9998                 19.184621
# 9999                 16.365792
#
# [10000 rows x 9 columns]

# %%
Y
# Out:
#       Elongation(%)  Conductivity(%IACS)    UTS(Mpa)
# 0         79.004379            46.183274  151.816979
# 1         78.148739            45.231306  149.161207
# 2         76.589026            43.895326  141.849935
# 3         66.702291            43.427165  157.580112
# 4         73.947378            44.451037  163.040135
# ...             ...                  ...         ...
# 9995      70.246691            42.916029  162.476887
# 9996      70.575571            44.014963  151.391820
# 9997      75.721106            45.213703  144.549297
# 9998      77.175560            43.742988  154.972563
# 9999      70.947047            44.780476  155.620165
#
# [10000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , Y , test_size= 0.2)

# %%
len(X_train)
# Out:
# 8000

# %%
len(X_test)
# Out:
# 2000

# %%
len(y_train)
# Out:
# 8000

# %%
len(y_test)
# Out:
# 2000

# %%
X_train.shape
# Out:
# (8000, 9)

# %%
y_train.shape
# Out:
# (8000, 3)

# %%
X_train.head()
# Out:
#       CastingTemperature(C)  RollingSpeed(m/min)  CoolingRate(C/s)  \
# 7050             518.030015             2.105835          0.569886
# 1657             472.282236             2.151071          2.458707
# 7238             491.926433             2.442463          1.732410
# 2611             510.638562             3.402625          1.074309
# 6351             474.428203             3.884996          0.596119
#
#       ChemicalComposition(Al%)  ChemicalComposition(Cu%)  \
# 7050                 97.209623                  1.429350
# 1657                 98.758419                  0.461259
# 7238                 95.867587                  1.386258
# 2611                 98.899356                  1.006325
# 6351                 95.748079                  0.663181
#
#       ChemicalComposition(Fe%)  EmulsionTemperature(C)  EmulsionPressure(Bar)  \
# 7050                  0.550361               45.947392               2.932940
# 1657                  0.385224               55.441143               2.569008
# 7238                  0.107204               47.202886               1.802057
# 2611                  0.458519               65.109287               1.556286
# 6351                  0.193300               36.378122               2.423012
#
#       EmulsionConcentration(%)
# 7050                  8.042326
# 1657                 12.077021
# 7238                  8.043476
# 2611                 16.210766
# 6351                 12.103007

# %%
y_train.head()
# Out:
#       Elongation(%)  Conductivity(%IACS)    UTS(Mpa)
# 7050      77.972482            43.310006  150.007713
# 1657      74.197752            46.495407  154.708146
# 7238      72.014071            43.921526  162.574850
# 2611      76.336956            46.070336  153.700056
# 6351      71.261941            42.928196  157.370614

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
lrmodel = LinearRegression()
lrmodel.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
lrmodel.predict(X_test)
# Out:
# array([[ 68.51397968,  43.26639124, 150.33868295],
#        [ 74.06857663,  42.47013111, 150.44708633],
#        [ 72.24660263,  43.67170559, 150.6585119 ],
#        ...,
#        [ 71.98014763,  44.0275805 , 150.42579936],
#        [ 68.39684916,  41.58886318, 150.54916922],
#        [ 71.90451103,  45.21852225, 150.90154453]])

# %%
lrmodel.predict([[517.738762,2.670609,2.124924,97.462870,1.343437,0.490581,57.784047,2.021540,10.924512]])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 78.62474658,  45.82896893, 150.93429528]])

# %%
lrmodel.predict([[514.097405,4.114840,2.440798,97.577301,0.732053,0.114230,35.371321,1.189000,15.647929]])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 78.41126671,  43.79325602, 150.65577783]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X_train_prediction = lrmodel.predict(X_train)
mae = mean_absolute_error(X_train_prediction , y_train)
mse = mean_squared_error(X_train_prediction , y_train)
rmse = np.sqrt(mse)
r2 = r2_score(X_train_prediction , y_train)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 2.5923326541610954
# Mean Squared Error (MSE): 19.88405950063489
# Root Mean Squared Error (RMSE): 4.459154572408865
# R-squared (R²): -159.1555014886038

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X_test_prediction = lrmodel.predict(X_test)
mae = mean_absolute_error(X_test_prediction , y_test)
mse = mean_squared_error(X_test_prediction , y_test)
rmse = np.sqrt(mse)
r2 = r2_score(X_test_prediction , y_test)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 2.5866962099711546
# Mean Squared Error (MSE): 19.905639283351924
# Root Mean Squared Error (RMSE): 4.46157363307521
# R-squared (R²): -165.1712302515526

# %%
dtmodel = DecisionTreeRegressor()
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtmodel.predict(X_test)
# Out:
# array([[ 68.50891178,  43.25797233, 146.3174641 ],
#        [ 74.70620734,  43.3933103 , 149.1574487 ],
#        [ 70.77204412,  44.15217283, 164.1021499 ],
#        ...,
#        [ 71.64033769,  44.60281898, 163.4417619 ],
#        [ 66.19912887,  42.15300446, 144.646028  ],
#        [ 73.0731815 ,  46.3172765 , 155.4169527 ]])

# %%
dtmodel.predict([[517.738762,2.670609,2.124924,97.462870,1.343437,0.490581,57.784047,2.021540,10.924512]])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([[ 79.00437948,  46.18327437, 151.8169788 ]])

# %%
dtmodel.predict([[514.097405,4.114840,2.440798,97.577301,0.732053,0.114230,35.371321,1.189000,15.647929]])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([[ 76.58902554,  43.89532644, 141.8499348 ]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X_train_prediction = dtmodel.predict(X_train)
mae = mean_absolute_error(X_train_prediction , y_train)
mse = mean_squared_error(X_train_prediction , y_train)
rmse = np.sqrt(mse)
r2 = r2_score(X_train_prediction , y_train)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 0.0
# Mean Squared Error (MSE): 0.0
# Root Mean Squared Error (RMSE): 0.0
# R-squared (R²): 1.0

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X_test_prediction = dtmodel.predict(X_test)
mae = mean_absolute_error(X_test_prediction , y_test)
mse = mean_squared_error(X_test_prediction , y_test)
rmse = np.sqrt(mse)
r2 = r2_score(X_test_prediction , y_test)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 3.8445204677383296
# Mean Squared Error (MSE): 42.86960743992051
# Root Mean Squared Error (RMSE): 6.547488636104725
# R-squared (R²): 0.015127555354571554

# %%
rfmodel =  RandomForestRegressor()
rfmodel.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfmodel.predict(X_test)
# Out:
# array([[ 68.82923784,  43.58864887, 148.31994091],
#        [ 74.38146406,  43.23207409, 150.10416497],
#        [ 72.00485572,  43.75341134, 149.62845743],
#        ...,
#        [ 72.06114666,  43.91096723, 150.66605728],
#        [ 68.80806798,  42.85511391, 148.77953419],
#        [ 71.7006735 ,  45.37466648, 149.02098435]])

# %%
rfmodel.predict([[517.738762,2.670609,2.124924,97.462870,1.343437,0.490581,57.784047,2.021540,10.924512]])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([[ 78.72836877,  46.05207978, 151.32642541]])

# %%
rfmodel.predict([[514.097405,4.114840,2.440798,97.577301,0.732053,0.114230,35.371321,1.189000,15.647929]])
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([[ 77.17853916,  43.81938758, 146.35253339]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X_train_prediction = rfmodel.predict(X_train)
mae = mean_absolute_error(X_train_prediction , y_train)
mse = mean_squared_error(X_train_prediction , y_train)
rmse = np.sqrt(mse)
r2 = r2_score(X_train_prediction , y_train)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 1.0036787323022127
# Mean Squared Error (MSE): 2.942534550852804
# Root Mean Squared Error (RMSE): 1.715381750763603
# R-squared (R²): 0.8572671247496796

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
X_test_prediction = rfmodel.predict(X_test)
mae = mean_absolute_error(X_test_prediction , y_test)
mse = mean_squared_error(X_test_prediction , y_test)
rmse = np.sqrt(mse)
r2 = r2_score(X_test_prediction , y_test)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 2.682137363471233
# Mean Squared Error (MSE): 20.962550928138782
# Root Mean Squared Error (RMSE): 4.578487842960684
# R-squared (R²): -5.617551754445555

# %%
input_data = (514.097405,4.114840,2.440798,97.577301,0.732053,0.114230,35.371321,1.189000,15.647929)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1 , -1)
prediction = lrmodel.predict(input_data_reshaped)
prediction
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 78.41126671,  43.79325602, 150.65577783]])

# %%
CastingTemperature = float(input(""))
RollingSpeed = float(input(""))
CoolingRate = float(input(""))
ChemicalCompositionAl = float(input(""))
ChemicalCompositionCu = float(input(""))
ChemicalCompositionFe = float(input(""))
EmulsionTemperature = float(input(""))
EmulsionPressure = float(input(""))
EmulsionConcentration = float(input(""))
# Out:
#  514.097405
#  4.114840
#  2.440798
#  97.577301
#  0.732053
#  0.114230
#  35.371321
#  1.189000
#  15.647929

# %%
input_data = (CastingTemperature,RollingSpeed,CoolingRate,ChemicalCompositionAl,ChemicalCompositionCu,ChemicalCompositionFe,EmulsionTemperature,EmulsionPressure,EmulsionConcentration)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1 , -1)
prediction = lrmodel.predict(input_data_reshaped)
prediction
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 78.41126671,  43.79325602, 150.65577783]])

# %%
import pickle
with open("aluminium_model_pickle" , "wb") as file:
     pickle.dump(lrmodel , file)

# %%
import numpy as np
import pickle
with open("aluminium_model_pickle" , "rb") as file:
     lrmodel = pickle.load(file)

# %%
input_data = (514.097405,4.114840,2.440798,97.577301,0.732053,0.114230,35.371321,1.189000,15.647929)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1 , -1)
prediction = lrmodel.predict(input_data_reshaped)
prediction
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 78.41126671,  43.79325602, 150.65577783]])
